# %%
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Bidirectional, SimpleRNN, Dense, LSTM, GRU

# %%
## Load the imdb dataset
num_words=10000 # Number of words to keep
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=num_words)

# pad sequences to have the same length
maxlen=100 # Maximum sequence length
x_train = pad_sequences(x_train, maxlen=maxlen, padding="post", truncating="post")
x_test = pad_sequences(x_test, maxlen=maxlen, padding="post", truncating="post")

print(x_train.shape)
x_train[0]
# maxi= [max(x_train[i]) for i in range(101)]
# print(maxi)

# for i in range(101):
#     print(max(x_train[i]))
# Out:
# (25000, 100)
# array([   1,   14,   22,   16,   43,  530,  973, 1622, 1385,   65,  458,
#        4468,   66, 3941,    4,  173,   36,  256,    5,   25,  100,   43,
#         838,  112,   50,  670,    2,    9,   35,  480,  284,    5,  150,
#           4,  172,  112,  167,    2,  336,  385,   39,    4,  172, 4536,
#        1111,   17,  546,   38,   13,  447,    4,  192,   50,   16,    6,
#         147, 2025,   19,   14,   22,    4, 1920, 4613,  469,    4,   22,
#          71,   87,   12,   16,   43,  530,   38,   76,   15,   13, 1247,
#           4,   22,   17,  515,   17,   12,   16,  626,   18,    2,    5,
#          62,  386,   12,    8,  316,    8,  106,    5,    4, 2223, 5244,
#          16], dtype=int32)

# %%
# Build the Bidirectional RNN model

from keras.layers import Input

num_words=10000
embedding_dim=32 # Embedding dimension layer
maxlen=100
model = Sequential([
    Input(shape=(maxlen,)),  # This tells the model to expect sequences of 100 integers
    Embedding(num_words, embedding_dim), # You can remove input_length here now
    SimpleRNN(5), # 5 RNN units
    Dense(1, activation='sigmoid') # Binary Classification (positive/negative)
])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 100, 32)        │       320,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ (None, 5)              │           190 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 320,196 (1.22 MB)
#  Trainable params: 320,196 (1.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# compile the model
model.compile(optimizer='adam', loss="binary_crossentropy", metrics=["accuracy"])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
# train the model
history= model.fit(x_train, y_train, epochs=5, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 28s 40ms/step - accuracy: 0.5351 - loss: 0.6898 - val_accuracy: 0.5240 - val_loss: 0.6988
# Epoch 2/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 42s 41ms/step - accuracy: 0.7200 - loss: 0.5825 - val_accuracy: 0.7476 - val_loss: 0.5470
# Epoch 3/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 38ms/step - accuracy: 0.8030 - loss: 0.4601 - val_accuracy: 0.7558 - val_loss: 0.5196
# Epoch 4/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 30ms/step - accuracy: 0.8650 - loss: 0.3593 - val_accuracy: 0.7668 - val_loss: 0.5190
# Epoch 5/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 38ms/step - accuracy: 0.8946 - loss: 0.2978 - val_accuracy: 0.7384 - val_loss: 0.6075

# %%
# Build the Bidirectional RNN model

from keras.layers import Input

num_words=10000
embedding_dim=32 # Embedding dimension layer
maxlen=100
model = Sequential([
    Input(shape=(maxlen,)),  # This tells the model to expect sequences of 100 integers
    Embedding(num_words, embedding_dim), # You can remove input_length here now
    Bidirectional(SimpleRNN(5)), # 5 RNN units
    Dense(1, activation='sigmoid') # Binary Classification (positive/negative)
])

# Display the model architecture 
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (None, 100, 32)        │       320,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 10)             │           380 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 320,391 (1.22 MB)
#  Trainable params: 320,391 (1.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# compile the model
model.compile(optimizer='adam', loss="binary_crossentropy", metrics=["accuracy"])

# %%
# train the model
history= model.fit(x_train, y_train, epochs=5, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 70ms/step - accuracy: 0.6031 - loss: 0.6583 - val_accuracy: 0.6896 - val_loss: 0.6067
# Epoch 2/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 33s 53ms/step - accuracy: 0.7459 - loss: 0.5211 - val_accuracy: 0.7022 - val_loss: 0.5851
# Epoch 3/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 55ms/step - accuracy: 0.8518 - loss: 0.3597 - val_accuracy: 0.7450 - val_loss: 0.5802
# Epoch 4/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 33s 53ms/step - accuracy: 0.9234 - loss: 0.2193 - val_accuracy: 0.7192 - val_loss: 0.6624
# Epoch 5/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 42s 53ms/step - accuracy: 0.9582 - loss: 0.1381 - val_accuracy: 0.7110 - val_loss: 0.7266

# %%
# Define the Deep LSTM model

from keras.layers import Input

model = Sequential([
    Input(shape=(100,)),  # This tells the model to expect sequences of 100 integers
    Embedding(10000, 32), # You can remove input_length here now
    Bidirectional(LSTM(5)),
    Dense(1, activation='sigmoid')
])

# Display the model architecture 
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)         │ (None, 100, 32)        │       320,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_2 (Bidirectional) │ (None, 10)             │         1,520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 321,531 (1.23 MB)
#  Trainable params: 321,531 (1.23 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# compile the model
model.compile(optimizer='adam', loss="binary_crossentropy", metrics=["accuracy"])

# %%
# train the model
history= model.fit(x_train, y_train, epochs=5, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 55s 76ms/step - accuracy: 0.7370 - loss: 0.5190 - val_accuracy: 0.8128 - val_loss: 0.4337
# Epoch 2/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 43s 68ms/step - accuracy: 0.8630 - loss: 0.3306 - val_accuracy: 0.8204 - val_loss: 0.4161
# Epoch 3/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 42s 67ms/step - accuracy: 0.9031 - loss: 0.2493 - val_accuracy: 0.8318 - val_loss: 0.4110
# Epoch 4/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 83s 68ms/step - accuracy: 0.9327 - loss: 0.1849 - val_accuracy: 0.8254 - val_loss: 0.4672
# Epoch 5/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 37s 59ms/step - accuracy: 0.9523 - loss: 0.1363 - val_accuracy: 0.8196 - val_loss: 0.5149

# %%
# Define the Deep GRU model

from keras.layers import Input

model = Sequential([
    Input(shape=(100,)),  # This tells the model to expect sequences of 100 integers
    Embedding(10000, 32), # You can remove input_length here now
    Bidirectional(GRU(5)),
    Dense(1, activation='sigmoid')
])

# Display the model architecture 
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_4 (Embedding)         │ (None, 100, 32)        │       320,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_3 (Bidirectional) │ (None, 10)             │         1,170 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 321,181 (1.23 MB)
#  Trainable params: 321,181 (1.23 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# compile the model
model.compile(optimizer='adam', loss="binary_crossentropy", metrics=["accuracy"])

# %%
# train the model
history= model.fit(x_train, y_train, epochs=5, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 55s 76ms/step - accuracy: 0.6930 - loss: 0.5679 - val_accuracy: 0.7976 - val_loss: 0.4506
# Epoch 2/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 47s 75ms/step - accuracy: 0.8548 - loss: 0.3480 - val_accuracy: 0.8222 - val_loss: 0.3985
# Epoch 3/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 59s 94ms/step - accuracy: 0.9033 - loss: 0.2503 - val_accuracy: 0.8082 - val_loss: 0.4430
# Epoch 4/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 88s 104ms/step - accuracy: 0.9330 - loss: 0.1814 - val_accuracy: 0.8162 - val_loss: 0.4792
# Epoch 5/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 101ms/step - accuracy: 0.9560 - loss: 0.1280 - val_accuracy: 0.8110 - val_loss: 0.5478
